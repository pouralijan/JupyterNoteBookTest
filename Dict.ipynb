# %%
import threading
import pyperclip
import time
import goslate
from google.cloud import translate
from googletrans import Translator
from googletrans import models

# %%
def print_to_stdout(clipboard_content):
    #print (str(clipboard_content))
    #translator = Translator()
    #print(translator.translate(str(clipboard_content), dest='fa').text)

    gs = goslate.Goslate()
    translatedText = gs.translate(str(clipboard_content),'fa')
    print(translatedText)
    #gs = goslate.Goslate()
    #gs.lookup_dictionary(str(clipboard_content), 'fa')

# %%
class ClipboardWatcher(threading.Thread):
    def __init__(self, callback):
        super(ClipboardWatcher, self).__init__()
        self._callback = callback
        self._stopping = False

    def run(self):       
        recent_value = pyperclip.paste()
        while not self._stopping:
            tmp_value = pyperclip.paste()
            if tmp_value != recent_value:
                recent_value = tmp_value
                self._callback(recent_value)
    def stop(self):
        self._stopping = True

# %%
watcher = ClipboardWatcher(print_to_stdout)
watcher.start()
# Out:
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "<ipython-input-3-3afd0a9d5523>", line 13, in run
#     self._callback(recent_value)
#   File "<ipython-input-2-f85a7b53a283>", line 7, in print_to_stdout
#     translatedText = gs.translate(str(clipboard_content),'fa')
#   File "/usr/lib/python3.6/site-packages/goslate.py", line 409, in translate
#     return _unwrapper_single_element(self._translate_single_text(text, target_language, source_language))
#   File "/usr/lib/python3.6/site-packages/goslate.py", line 334, in _translate_single_text
#     results = list(self._execute(make_task(i) for i in split_text(text)))
#   File "/usr/lib/python3.6/site-packages/goslate.py", line 203, in _execute
#     yield each()
#   File "/usr/lib/python3.6/site-packages/goslate.py", line 332, in <lambda>
# ...

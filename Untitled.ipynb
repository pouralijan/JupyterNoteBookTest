# %%
import requests
import bs4
import re

not_found_count = 0
objs=[]
url = 'https://maktabkhooneh.org/courses?tags=%DA%A9%D8%A7%D9%85%D9%BE%DB%8C%D9%88%D8%AA%D8%B1'
#for i in range(1,50):
#    new_url = url.format(i)
#    print(new_url)
page = requests.get(url)
#if page.status_code == 404:
#    print(url, '>>> Not found, 404' )
#    not_found_count +=1
#    print(not_found_count)
#    if not_found_count > 2:
#        break
#    continue
soup = bs4.BeautifulSoup(page.content, "html.parser")
objs = soup.select(".overlay-name")[:-1]
print(objs)

exit()

print(len(objs))
for obj in objs:
    if obj.text == '':
        continue
    #print ('{} -> {}'.format(obj.text, obj.get('href'),))
    page = requests.get(obj.get('href'))
    if page.status_code == 404:
        continue
    soup = bs4.BeautifulSoup(page.content, "html.parser")
    size = soup.select(".circle-yes+ span")
    
    publisher = soup.select('.en-title')
    if publisher:
        print (publisher[0].text)
    continue
    publisher = soup.select('.en-publisher')
    if publisher:
        print (publisher[0].text)
    
    publisher = soup.select('.en-duration')
    if publisher:
        print (publisher[0].text)
        
    publisher = soup.select('.en-level')
    if publisher:
        print (publisher[0].text)
    
    publisher = soup.select('.en-link')
    if publisher:
        print ("{}: {}".format(publisher[0].text.split(':', 1)[0], publisher[0].text.split(':', 1)[1]))
    
    publisher = soup.select('.en-description')
    if publisher:
        print (publisher[0].text)
        
    publisher = soup.select('.en-headlines')
    #if publisher:
    #    print (publisher[0].text)
        
    print(size)
    links = soup.select(".fusion-li-item a")
    for link in links:
        print(link.get('href'))
# Out:
# [<div class="overlay-name">
# <span id="name_val">طراحی و پیاده‌سازی سیستم‌ها با آردوینو</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش برنامه‌نویسی با نرم‌افزار متلب MATLAB</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدیریت عملیات</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نرم‌افزار COMFAR III به همراه مبانی مطالعات اقتصادی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی وب سایت (Front-End)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش اندروید</span>
# </div>, <div class="overlay-name">
# <span id="name_val">محاسبات عددی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک سیالات محاسباتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">توربو ماشین</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تحلیل سازه های هوافضایی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">سیستم های مخابراتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی سازه های بتنی 1 </span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی کشتی با کامپیوتر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نرم افزار HSpice</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی کشتی های ویژه</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نکاتی مفيد براي تهيه مقاله علمي در مجلات انگلیسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک متحرکهای دریایی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مهندسی اقیانوس</span>
# </div>, <div class="overlay-name">
# <span id="name_val">زیردریایی رادیو کنترلی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نشست‌های سیاست گذاری عمومی با رویکرد رفتاری</span>
# </div>, <div class="overlay-name">
# <span id="name_val">زبان برنامه نویسی(المپیاد کامپیوتر)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">گراف(المپیاد کامپیوتر)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الگوریتم(المپیاد کامپیوتر)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ادوات حالت جامد پیشرفته</span>
# </div>, <div class="overlay-name">
# <span id="name_val">محاسبات ماتریسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک سیالات 1</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تحلیل و طراحی سیستم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هوش مصنوعی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کارگاه تصویربرداری مغزی (ساختاری و عملکردی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فنون مذاکره</span>
# </div>, <div class="overlay-name">
# <span id="name_val">شبیه سازی شی گرای سیستم های الکترونیکی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">پایگاه داده ها (به روش کاربردی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی برنامه نویسی کامپیوتر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">میدان و امواج</span>
# </div>, <div class="overlay-name">
# <span id="name_val">روش های تولید</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مقدمه ای بر مهندسی پزشکی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">متالوژی در تولید</span>
# </div>, <div class="overlay-name">
# <span id="name_val">سیستم های تبرید و سردخانه</span>
# </div>, <div class="overlay-name">
# <span id="name_val">verilog</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ساختمان داده ها و الگوریتم ها</span>
# </div>, <div class="overlay-name">
# <span id="name_val">پردازش زبان های طبیعی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی مدیریت استراتژیک + گفت‌وگوی ویژه با پروفسور رابرت گرنت</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی مدارهای آنالوگ</span>
# </div>, <div class="overlay-name">
# <span id="name_val">برنامه‌نویسی حرفه‌ای تحت وب در جاوا</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحث منتخب مدیریت و تکنولوژی - پاییز 1395</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فلسفه ریاضی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای منطقی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدل‌ کسب‌وکارهای پلتفرمی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اندازه گیری و سیستم های کنترل</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک آشوب</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش آلتیوم (Altium)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">یادگیری ماشین</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی سیستم های دیجیتالی کم توان</span>
# </div>, <div class="overlay-name">
# <span id="name_val">علم مواد</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ترمودینامیک 2</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک خاک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مقدمات طراحی دیجیتال RTL و Verilog</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای الکتریکی 1</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش لتک (LaTeX)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی مهندسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای منطقی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ارتعاشات غیرخطی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نظریه الگوریتم پیشرفته</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحث منتخب در اقتصاد کلان</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کیهان شناسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">شیمی آلی فلزی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تکنولوژی کشتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مهندسی نرم افزار 2 (به روش کاربردی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحث منتخب مدیریت و تکنولوژی - پاییز 1392</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تحقیق در عملیات پیشرفته ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک تحلیلی 1</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش مقدماتیActive VHDL</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک 3</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترومغناطیس ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">همایش داروسازی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">استاندارد طراحی کشتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مطالعه و مداخله در علوم اعصاب شناختی (دوره تکمیلی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریزپردازنده 2</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اصول طراحی پایگاه داده ها</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی فیزیک ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">برنامه نویسی پیشرفته(جاوا)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی اجزاء 1</span>
# </div>, <div class="overlay-name">
# <span id="name_val">استاتیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کم شنوایی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هیدرولیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هیدرودینامیک محیط زیست</span>
# </div>, <div class="overlay-name">
# <span id="name_val">شیمی عمومی ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">روانشناسی اجتماعی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک سیالات ۱ </span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی الگوریتم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">برنامه سازی پیشرفته</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هوش مصنوعی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نظریه گروه</span>
# </div>, <div class="overlay-name">
# <span id="name_val">روشهای مطالعه و مداخله در علوم اعصاب شناختی (دوره مقدماتی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با اختلال پردازش شنیداری – بدشنوایی در کودکان</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش پیشرفته کار با اسیلوسکوپ</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش مقدماتی کار با اسیلوسکوپ </span>
# </div>, <div class="overlay-name">
# <span id="name_val">هیدرواستاتيک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی فیزیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هیدرودینامیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مقدمه ای بر مهندسی مکانیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الگوریتم های داده های حجیم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی علوم اعصاب شناختی </span>
# </div>, <div class="overlay-name">
# <span id="name_val">درمان ۳</span>
# </div>, <div class="overlay-name">
# <span id="name_val">درمان  ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">پایگاه داده</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آنالیز ریاضی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدیریت ریسک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مهندسی اینترنت</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آزمایشگاه مقاومت مصالح</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش yii framework 2</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ویروس شناسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با صنایع شیمی کشور</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هواشناسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آمار در تجارت</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش سریع درس  مدارهای منطقی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کارآموزی داروسازی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">درمان  ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترونیک نوری</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک پرواز</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کنترل خطی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اخلاق مهندسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با متون علمی شیمی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">منطق ریاضی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی الگوریتم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی فیزیک ١ </span>
# </div>, <div class="overlay-name">
# <span id="name_val">برنامه نویسی پیشرفته</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای الکتریکی ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">بازاریابی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ترمودینامیک ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی آنالیز ریاضی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش مقدماتی زبان انگلیسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ترمودینامیک و مکانیک آماری غیر تعادلی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحثی در آنالیز عددی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تشخیص الگو</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک کوانتیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک آماری</span>
# </div>, <div class="overlay-name">
# <span id="name_val">سیاه چاله</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش متمتیکا (Mathematica)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش HSpice</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش PSpice</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با لتکس و نحوه ارسال مقالات ISI</span>
# </div>, <div class="overlay-name">
# <span id="name_val">داده کاوی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی اقتصاد</span>
# </div>, <div class="overlay-name">
# <span id="name_val">برنامه ریزی استراتژیک در عمل</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با موسیقی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش لتکس (LATEX)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش MAYA</span>
# </div>, <div class="overlay-name">
# <span id="name_val">پروژه راه با استفاده از Civil3D</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارات الکترونیک ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">میکروکنترلرهای AVR</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نظریه اعداد - آمادگی مرحله ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">جبر - آمادگی مرحله ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هندسه - آمادگی مرحله ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ترکیبیات - آمادگی مرحله ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای آنالوگ</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تئوری سازه ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نجوم مقدماتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اقتصاد کلان ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تئوری اطلاعات شبکه</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اصول پیشرانش (جلوبرندگی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدیریت راهبردی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تحلیل دینامیک های سیستم (بهار ۱۳۹۴)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحث منتخب مدیریت و تکنولوژی - پاییز1394</span>
# </div>, <div class="overlay-name">
# <span id="name_val">معرفی رشته‌ها</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی نظریه محاسبه</span>
# </div>, <div class="overlay-name">
# <span id="name_val">VLSI</span>
# </div>, <div class="overlay-name">
# <span id="name_val">میدان های كوانتومی ٢ - ١٣٨٩</span>
# </div>, <div class="overlay-name">
# <span id="name_val">احتمال ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مبانی مهندسی زلزله</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با رشد اقتصادی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ارتعاشات</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی عمومی ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی وب  Codeigniter </span>
# </div>, <div class="overlay-name">
# <span id="name_val">فلسفه علم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آئرودینامیک ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مقاومت مصالح ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">قابلیت اعتماد سازه و مدل سازی احتمالاتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">Aircraft Performance</span>
# </div>, <div class="overlay-name">
# <span id="name_val">پردازش سیگنالهای دیجیتال</span>
# </div>, <div class="overlay-name">
# <span id="name_val">میدان های كوانتومی ١ - ١٣٩٣ </span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک سیالات</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحث منتخب در مالی ٢</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک غیر خطی و آشوب</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اصول الکترونیک (الکترونیک ۲)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مقدمه‌ای بر بیوانفورماتیک (تحلیل داده‌های زیستی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی فیزیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">سیستم های انرژی الکتریکی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ساختمان داده ها</span>
# </div>, <div class="overlay-name">
# <span id="name_val">بانکداری اسلامی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اصول ادوات حالت جامد</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تحلیل دینامیک های سیستم (بهار ۱۳۹٣)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">شبکه مخابرات داده پیشرفته</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مباحث منتخب در مالی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای مجتمع فرکانس بالا - RFIC</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دروس المپیاد ریاضی  </span>
# </div>, <div class="overlay-name">
# <span id="name_val">دروس المپیاد فیزیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دروس المپیاد کامپیوتر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اخلاق فناوری اطلاعات (مهندسی IT)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نسبیت خاص</span>
# </div>, <div class="overlay-name">
# <span id="name_val">سلول های خورشیدی ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اقتصاد خرد- دوره فرعی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ساختار کامپیوتر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای واسط کامپیوتری</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای مخابراتی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">تکنیک پالس</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آشنایی با ریاضیات</span>
# </div>, <div class="overlay-name">
# <span id="name_val">معادلات دیفرانسيل</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کیهان شناسی ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">گرانش و نسبیت عام ٢</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدارهای CMOS</span>
# </div>, <div class="overlay-name">
# <span id="name_val">نظریه بازی ها</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترومغناطیس ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">گرانش و نسبیت عام ١</span>
# </div>, <div class="overlay-name">
# <span id="name_val">دینامیک ماشین</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ماشین های الکتریکی ٢ و ٣</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترونیک ۳</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مدار های منطقی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">بیوفیزیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضیات گسسته</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی مهندسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریزپردازنده ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آمار و احتمال مهندسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک کوانتیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">طراحی اجزا ماشین ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">سیگنال و سيستم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">برنامه نویسی وب</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کنترل اتوماتیک (کنترل خطی)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ترمودینامیک و مکانیک آماری ٢</span>
# </div>, <div class="overlay-name">
# <span id="name_val">معادلات دیفرانسیل</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش مقدماتی SPICE</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اصول برنامه نویسی C و ++C</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش AutoCad</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش مقدماتی Python</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش Dreamweaver</span>
# </div>, <div class="overlay-name">
# <span id="name_val">جبر خطی </span>
# </div>, <div class="overlay-name">
# <span id="name_val">خلاقیت با لگو</span>
# </div>, <div class="overlay-name">
# <span id="name_val">FPGA کاربردی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">میکرو کنترل کاربردی </span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش فتوشاپ (Photoshop)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ترمودینامیک و مکانیک آماری ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترونیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک کوانتیک ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">کیهان شناسی </span>
# </div>, <div class="overlay-name">
# <span id="name_val">کاربرد کامپیوتر درفیزیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">معماری کامپیوتر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">شبکه مخابرات داده</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش Protel DXP</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آزمایشگاه شیمی </span>
# </div>, <div class="overlay-name">
# <span id="name_val">سرگرمی های فیزیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترونیک ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش ASP.net</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش مقدماتی متلب (Matlab)</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش FPGA</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک کلاسیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آموزش LabVIEW</span>
# </div>, <div class="overlay-name">
# <span id="name_val">میکروکنترلر ARM</span>
# </div>, <div class="overlay-name">
# <span id="name_val">جبر ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اصول فلسفی مکانیک کوانتوم</span>
# </div>, <div class="overlay-name">
# <span id="name_val">RFIC ، مدارات فشرده فرکانس بالا</span>
# </div>, <div class="overlay-name">
# <span id="name_val">یادگیری ماشین </span>
# </div>, <div class="overlay-name">
# <span id="name_val">تبدیل فوریه و کاربردهای آن </span>
# </div>, <div class="overlay-name">
# <span id="name_val">آنالیز ریاضی ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فرآیند تصادفی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">الکترونیک ۱</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ارز</span>
# </div>, <div class="overlay-name">
# <span id="name_val">توابع مختلط</span>
# </div>, <div class="overlay-name">
# <span id="name_val">احتمال</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اقتصاد کنونی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مکانیک کوانتیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضی عمومی ۲</span>
# </div>, <div class="overlay-name">
# <span id="name_val">جبر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">بانکداری و پول</span>
# </div>, <div class="overlay-name">
# <span id="name_val">حسابان</span>
# </div>, <div class="overlay-name">
# <span id="name_val">آمار</span>
# </div>, <div class="overlay-name">
# <span id="name_val">هندسه</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اقتصاد خرد</span>
# </div>, <div class="overlay-name">
# <span id="name_val">جبر خطی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ارزیابی و سرمایه گذاری</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اختر شناسی و ستاره شناسی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">حساب</span>
# </div>, <div class="overlay-name">
# <span id="name_val">علوم کامپیوتر</span>
# </div>, <div class="overlay-name">
# <span id="name_val">علم مالی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">شیمی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">مثلثات</span>
# </div>, <div class="overlay-name">
# <span id="name_val">فیزیک</span>
# </div>, <div class="overlay-name">
# <span id="name_val">معادلات دیفرانسیل</span>
# </div>, <div class="overlay-name">
# <span id="name_val">اقتصاد کلان</span>
# </div>, <div class="overlay-name">
# <span id="name_val">ریاضیات مالی</span>
# </div>, <div class="overlay-name">
# <span id="name_val">جبر خطی</span>
# </div>]
# 0
